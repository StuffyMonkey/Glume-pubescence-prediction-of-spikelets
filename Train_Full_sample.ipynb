# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd
import numpy as np
import os
import cv2
import time
import random
import re
import sys
import albumentations as A
from numba import jit
from matplotlib import pyplot as plt
import torch
import torchvision
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision.models.feature_extraction import create_feature_extractor
from sklearn import metrics 
from scipy.ndimage import zoom

# %% [markdown]
# ## Check information about GPU

# %%
# !nvidia-smi
# Out:
# Mon Sep 19 11:36:43 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  Off  | 00000000:09:00.0 Off |                  N/A |
# | 31%   44C    P8    25W / 250W |      3MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  Off  | 00000000:0A:00.0 Off |                  N/A |
# | 37%   45C    P8    22W / 250W |  10660MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    1   N/A  N/A      9491      C   /opt/tljh/user/bin/python       10657MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Dataset class for our data

# %%
# to retrive one feature and lable one time
class SpikeletData(Dataset):
    def __init__(self, annotations_file, data_type='train', shuffle=False):
        
        # annotations file contains paths to images, labels, and belonging to the one of classes
        def data_target_split(file, data_type):
            x_data = []
            y_data = []
            with open(file) as inp:
                if shuffle:
                    data = [ (random.random(), line) for line in inp]
                    data.sort()
                    for _, line in data:
                        data = line.strip().split(';')
                        if data[2] == data_type:
                            x_data.append(data[0])
                            y_data.append(int(data[1]))
                else:
                    row = inp.readline().strip().split(';')
                    while len(row)>2:
                        if row[2] == data_type:
                            x_data.append(row[0])
                            y_data.append(int(row[1]))
                        row = inp.readline().strip().split(';')
            return x_data, y_data
                                  
        self.annotations_file = annotations_file
        self.data_type = data_type
        self.data, self.labels = data_target_split(annotations_file, data_type)
        
        
    def __len__(self):
        return len(self.data)
    

    def __getitem__(self, idx):
        
        # expand image to square of required size
        def get_square(img, size):
            x,y,z = img.shape
            if y < size and x >= size:
                square = np.zeros((x, size, 3), dtype='int')
            
                # Getting the centering position
                ax,ay = (x - img.shape[0])//2,(size - y)//2
            
                # Pasting the 'image' in a centering position
                if y % 2 == 0:
                    square[ax:x,ay:size-ay] += img
                else:
                    square[ax:x,ay:size-1-ay] += img
                np.count_nonzero(square)*100/(x*y*z)
                return square
            elif x < size and y >= size:
                square = np.zeros((size, y, 3), dtype='int')
                
                # Getting the centering position
                ax,ay = (size - x)//2,(y - img.shape[1])//2
            
                # Pasting the 'image' in a centering position
                if x % 2 == 0:
                    square[ax:size-ax,ay:y] += img
                else:
                    square[ax:size-1-ax,ay:y] += img
                np.count_nonzero(square)*100/(x*y*z)
                return square
            elif x < size and y < size:
                square = np.zeros((size, size, 3), dtype='int')
                
                # Getting the centering position
                ax,ay = (size - x)//2,(size - y)//2
            
                # Pasting the 'image' in a centering position
                if x%2 == 0 and y%2 == 0:
                    square[ax:-ax,ay:size-ay] += img
                elif x%2 == 0 and  y%2 != 0:
                    square[ax:size-ax,ay:size-1-ay] += img
                elif x%2 != 0 and y%2 == 0:
                    square[ax:size-1-ax,ay:size-ay] += img
                else:
                    square[ax:size-1-ax,ay:size-1-ay] += img
                np.count_nonzero(square)*100/(x*y*z)
                return square
                
        
        # read image and get label using path to image    
        def get_crop(img_path):
            ploid_patt = r'(Гексаплоиды)|(Диплоиды)|(Тетраплоиды)'
            pin_patt = r'[\d]{2,5}_(([^,(I|l)]_\{[XХI]+-?\d{2}\})|(\d))\.(jpg|JPG)$'
            spec_patt = r'T\.\s[a-z]*'
            table_patt = r'[\d]{2,5}((_{[ХXI]+-?\d{2}\})|())\.(jpg|JPG)$'
            
            # get data of ploidness and species to open segemented image
            ploid = re.search(ploid_patt, img_path).group()
            spec = re.search(spec_patt, img_path).group()    
            img_type = 'pin'
            img_name = re.search(pin_patt, img_path)
            if not img_name:
                img_type = 'table'
                img_name = re.search(table_patt, img_path)
            img_name = img_name.group()
            
            inp_dir = f'/home/jupyter-n.artemenko/projects/spikelet_pubescence/crops_without_spine/{ploid}/{spec}/{img_type}/{img_name}'
            inp_dir = inp_dir.replace('.jpg', '.png').replace('.JPG', '.png')
            inp_img = cv2.imread(inp_dir)
            if inp_img is None:
                print(inp_dir)
                
            res = None
            
            # different augmentations for images according to type of data
            if self.data_type=='train':
                # the first stage of augmentations
                transform_1 = A.Compose([
                    A.RandomScale((0.5, 1.5), p=0.7),
                    A.Blur(blur_limit=2, p=0.2)
                ])
                
                transform_2 = A.Compose([
                    A.CenterCrop(512, 512),
                    A.Flip(p=0.4)
                ])
                
                out_img = transform_1(image=inp_img)['image']
                size = 512
                
                # get square, if scaled image smaller, than training size
                if out_img.shape[0] < size or out_img.shape[1] < size:
                    out_img = get_square(out_img, size)
                
                out_img = transform_2(image=out_img)['image']
                x,y,z = out_img.shape
                
                # we don't need in crops without spikelets, so we add condition to number of nonzero
                # to the number of nonzero pixels
                percent = np.count_nonzero(out_img)*100/(x*y*z)    # percent of nonzero pixels
                count = 0
                while percent < 15 and count<100:
                    count += 1
                    out_img = transform_1(image=inp_img)['image']
                    if out_img.shape[0] < size or out_img.shape[1] < size:
                        out_img = get_square(out_img, size)
                    out_img = transform_2(image=out_img)['image']
                    percent = np.count_nonzero(out_img)*100/(x*y*z)
            
                # the second stage of augmentations
                transform = A.Compose([
                    A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
                ])
                
                out_img = out_img.astype(np.uint8)
                new_data = transform(image=out_img)
                res = new_data['image']
                
            elif self.data_type=='valid' or self.data_type=='test':
                size = 480
                res = inp_img.copy()
                if inp_img.shape[0] < size or inp_img.shape[1] < size:
                    res = get_square(inp_img, size)
                    
                transform = A.Compose([
                    A.CenterCrop(size,size)
                ])
                
                new_data = transform(image=res)
                res = new_data['image']
            else:
                print('''Error occured. Check your data_type and change to one of these:
                      \"train\", \"valid\" \"test\"''')
            
            # See the result
            # plt.imshow(res[:,:,::-1])
            
            # if you want to save obtained image
            # cv2.imwrite(f'/home/jupyter-n.artemenko/projects/spikelet_pubescence/test/{idx}.png', res)
            return res, spec
        
        current_sample = self.data[idx]
        current_target = self.labels[idx]
        img, species = get_crop(current_sample)
        
        # normalize image and move axis
        normalize = A.Compose([
            A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225), p=1.0)
        ])
        img_norm = normalize(image=img)['image']
        img_norm = np.moveaxis(img_norm, 2, 0)
        # img = np.moveaxis(img, 2, 0)
        # cv2.imwrite(f'{os.getcwd()}dssdsd.png', img)
        return torch.tensor(img_norm), current_target, idx, species.strip()

# %% [markdown]
# ## Define datasets for further learning process

# %%
data_source = '/home/jupyter-n.artemenko/projects/spikelet_pubescence/first_sample_split.txt'
train_data = SpikeletData(data_source, 'train')
valid_data = SpikeletData(data_source, 'valid')
test_data = SpikeletData(data_source, 'test')
dataset = torch.utils.data.ConcatDataset([train_data, valid_data, test_data])

# %% [markdown]
# ### Evaluate time of extraction one image

# %%
start = time.time()
sample_dataset = test_data
idx = random.randrange(0, sample_dataset.__len__())
print(idx)
print(sample_dataset.__getitem__(idx)[3])
print(time.time()-start)
# Out:
# 24
# T. boeoticum
# 0.032735347747802734

# %% [markdown]
# ## Focal loss

# %%
# it's not finished
class FocalLoss(nn.Module):
    def __init__(self, gamma=1, alpha=1, reduction='none', size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.reduction = reduction
        self.alpha = alpha
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)
        
        p = torch.sigmoid(input)
        ce_loss = F.binary_cross_entropy_with_logits(
            input, target, reduction="none"
        )
        p_t = p * target + (1 - p) * (1 - target)
        loss = ce_loss * ((1 - p_t) ** self.gamma)
        if self.alpha >= 0:
            alpha_t = self.alpha * target + (1 - self.alpha) * (1 - target)
            loss = alpha_t * loss

        if self.reduction == "mean":
            loss = loss.mean()
        elif self.reduction == "sum":
            loss = loss.sum()

        return loss

# %% [markdown]
# ## Class of model

# %%
class MyCNN():
    def __init__(self, save_path, loss, lr, wd):
        # load model
        self.model = torchvision.models.efficientnet_b1(pretrained=True)
        print(self.model.__dict__)
        self.model.classifier =  nn.Sequential(
            nn.Dropout(p=0.2, inplace=True),
            nn.Linear(in_features=1280, out_features=1),
            nn.Sigmoid())

        self.save_path = save_path
        self.model_name = model_name
        self.optimizer = optim.Adam(self.get_params(), lr=lr, weight_decay=wd)
        # self.optimizer = optim.SGD(self.get_params(), lr=1e-9, momentum=0.9)
        self.loss = loss
        
        self.device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
        self.model.to(self.device)
        
        
    # load weights of model
    def load(self):
        self.model.load_state_dict(torch.load(self.save_path))
        
    
    # gives parameters of model to optimization algorithms
    def get_params(self):
        return self.model.parameters()
    
    
    # show learning plots
    def training_data(self):
        try:
            data = pd.read_csv(self.save_path + '.csv')
            x_data = data['epoch'].tolist()
            figure, axs = plt.subplots(2, 2, figsize=(16, 10))
            
            # plot losses
            axs[0][0].set_title('Losses')
            y_data = data['training_loss'].tolist()
            axs[0][0].plot(x_data, y_data, color='black')
            y_data = data['valid_loss'].tolist()
            axs[0][0].plot(x_data, y_data, color='red')
            
            # plot accuracy
            axs[0][1].set_title('Accuracy')
            y_data = data['training_accuracy'].tolist()
            axs[0][1].plot(x_data, y_data, color='black', label = 'training')
            y_data = data['valid_accuracy'].tolist()
            axs[0][1].plot(x_data, y_data, color='red', label = 'valid')
            
            # plot precision
            axs[1][0].set_title('Precision')
            y_data = data['training_precision'].tolist()
            axs[1][0].plot(x_data, y_data, color='black', label = 'training')
            y_data = data['valid_precision'].tolist()
            axs[1][0].plot(x_data, y_data, color='red', label = 'valid')
            
            # plot auc
            axs[1][1].set_title('AUC')
            y_data = data['training_auc'].tolist()
            axs[1][1].plot(x_data, y_data, color='black', label = 'training')
            y_data = data['valid_auc'].tolist()
            axs[1][1].plot(x_data, y_data, color='red', label = 'valid')
            
            plt.legend()
        except FileNotFoundError:
            print("Please, check csv file with training loss and training data and path to it")
            
        
    @staticmethod
    def confusion_matrix(outputs, labels, threshold=0.5):
        # our confusion matrix will be look like |TN|FP|
        #                                        |FN|TP|
        matrix = np.zeros((2, 2), dtype=np.int16)
        for i in range(len(outputs)):
            # define prediction with threshold
            prediction = 1 if outputs[i].item() >= threshold else 0
            true_value = int(labels[i].item())
            matrix[true_value][prediction] += 1
        return matrix
        
      
    # show plots of species and predictions of model
    def show_errors(self, dataset):
        dataloader = DataLoader(dataset=dataset, batch_size=1, shuffle=True, num_workers=16)
        species_dist = {}
        
        # we don't need in computing gradients and changing weights of model
        self.model.eval()
        with torch.no_grad():
            for (inputs, labels, idxs, spec) in dataloader:
                # move the input and model to GPU for speed if available
                inputs = inputs.float()            
                labels = labels.unsqueeze(1)
            
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
            
                outputs = self.model(inputs)
                outputs = outputs.to(self.device)
                if spec[0] not in species_dist.keys():
                    species_dist[spec[0]] = np.zeros((2,2), dtype=np.int16)
                    
                # fill species_dist
                prediciton = 1 if outputs.item() >= 0.5 else 0
                label = labels.item()
                species_dist[spec[0]][label][prediciton] += 1
                
        # plots with classification data
        figure, axs = plt.subplots(len(species_dist), 1, figsize=(10, 100))
        for i, name in enumerate(species_dist.keys()):
            tmp = species_dist[name]
            x = np.reshape(tmp, (4))
            labels =['TN', 'FN', 'FP', 'TP']
            TN, FN, FP, TP = x
            accuracy = (TN + TP)/x.sum()
            # print(f'for species {name} we have: \n TN: {x[0]} \n FP: {x[1]}\n FN: {x[2]}\n TP: {x[3]}\n')
            print(f'for species {name} we have accuracy: {accuracy}')
            rect = axs[i].bar(labels, x, color='orange')
            axs[i].set_xlabel(name) 
            
            
    def class_activation_map(self, img, target):
        img_tensor = img.unsqueeze(0)
        img_tensor = img_tensor.to(self.device)
        
        output = self.model(img_tensor)
        conv_output = self.model.features(img_tensor)    # output of model before pooling
        
        prediction = 1 if output.item() >= 0.5 else 0
        
        # load weights if model was trained
        if os.path.exists(self.save_path):
            self.model.load_state_dict(torch.load(self.save_path))
            
        # extract weigts of the last layer before pooling
        w = 0
        for layer in list(self.model.named_parameters()):
            if layer[0] == 'features.8.1.weight':
                w = layer[1].cpu().detach().numpy()
            
        # acuire heatmap
        conv = conv_output.squeeze().cpu().detach().numpy()
        heatmap = 0
        for i in range(conv.shape[0]):
            heatmap += w[i]*conv[i]
        
        scale = 512 / 16
        plt.figure(figsize=(12, 12))
        
        img = img.detach().numpy()
        res = np.moveaxis(img, 0, 2)
        plt.imshow(res[:,:,::-1])
        plt.imshow(zoom(heatmap, zoom=(scale, scale)), cmap='jet', alpha=0.5)
        plt.savefig('heatmap.png')
        print(f"Target is: {target}", f"Prediction is: {prediction}", sep='\n')
                
        
    def run_epoch(self, dataloader, batch_sizes, data_type, threshold=0.5):
        # main variables
        running_loss = 0.0
        conf_matrix = np.zeros((2,2), dtype = np.int16)
        auc_matrices = np.zeros((11,2,2), dtype=np.int16)
        
        def auc_metric(matrices):
            True_Positive_Rate = []
            False_Positive_Rate = []
            for matrix in matrices:
                # TPR, FPR
                True_Positive_Rate.append(matrix[1][1]/(matrix[1][1] + matrix[1][0]))
                False_Positive_Rate.append(matrix[0][1]/(matrix[0][0] + matrix[0][1]))
                    
            AUC = 0
            for i in range(len(False_Positive_Rate)-1):
                l = (True_Positive_Rate[i+1]+True_Positive_Rate[i])/2
                h = False_Positive_Rate[i]-False_Positive_Rate[i+1]
                AUC += h*l
            return AUC
        
        def dataloader_loop():
            for (inputs, labels, idxs, spec) in dataloader:
                nonlocal running_loss, conf_matrix, auc_matrices
                # move the input and model to GPU for speed if available
                inputs = inputs.float()
                labels = labels.unsqueeze(1)
                labels = labels.float()
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)
                    
                outputs = self.model(inputs)
                outputs = outputs.to(self.device)
                loss = self.loss(outputs, labels)
                # backpropogating when on train data
                if data_type == 'train':
                    loss.backward()
                    self.optimizer.step()
                # compute auc
                for i in range(0,11):
                    tmp = self.confusion_matrix(outputs, labels, 0.1*i)
                    auc_matrices[i] += tmp
                    
                running_loss += loss.item()
                conf_matrix += self.confusion_matrix(outputs, labels, threshold)
        
        
        # preliminary preparation for loop
        if data_type == 'valid' or data_type == 'test':
            self.model.eval()
            with torch.no_grad():
                dataloader_loop()
        elif data_type == 'train':
            self.model.train()  
            dataloader_loop()
           
        # compute metrics and loss
        TP = conf_matrix[1][1]
        TN = conf_matrix[0][0]
        FP = conf_matrix[0][1]
        FN = conf_matrix[1][0]
        accuracy = (TP + TN)/(TP + FP + TN + FN)
        if TP + FP != 0:
            precision = TP/(TP + FP)
        else:
            precision = 0
        # print(auc_matrices)
        print(conf_matrix)
        auc = auc_metric(auc_matrices)
        loss = 0
        if data_type == 'valid' or data_type == 'test':
            loss = running_loss*batch_sizes[1]
        else:
            loss = running_loss*batch_sizes[0]
        
        # average loss by data_type
        if data_type == 'valid':
            loss = loss/valid_data.__len__()
        elif data_type == 'test':
            loss = loss/test_data.__len__()
        elif data_type == 'train':
            loss = loss/train_data.__len__()
        return loss, accuracy, precision, auc
    
    
    def fit(self, batch_sizes, epochs=10):      
        # we need to save information about learning process
        learning_data = {'epoch': [], 'training_loss': [], 'training_accuracy': [],
                        'training_precision': [], 'training_auc': [],'valid_loss': [], 
                         'valid_accuracy': [], 'valid_precision': [], 'valid_auc': []}
        
        # training loop
        train_generator = DataLoader(dataset=train_data, batch_size=batch_sizes[0], shuffle=True, num_workers=16)
        valid_generator = DataLoader(dataset=valid_data, batch_size=batch_sizes[1], shuffle=False, num_workers=16)
        for epoch in range(1, epochs+1):
            print(f'Epoch number: {epoch}')       
            # run training process and get data
            train_loss, train_accuracy, train_precision, train_auc = self.run_epoch(train_generator, 
                                                                            batch_sizes, data_type='train')
            
            valid_loss, valid_accuracy, valid_precision, valid_auc = self.run_epoch(valid_generator, 
                                                                            batch_sizes, data_type='valid')
                
            # write data to the table
            learning_data['epoch'].append(epoch)
            learning_data['training_loss'].append(train_loss)
            learning_data['training_accuracy'].append(train_accuracy)
            learning_data['training_precision'].append(train_precision)
            learning_data['training_auc'].append(train_auc)
            
            learning_data['valid_loss'].append(valid_loss)
            learning_data['valid_accuracy'].append(valid_accuracy)
            learning_data['valid_precision'].append(valid_precision)
            learning_data['valid_auc'].append(valid_auc)
            
            # print statistics
            print('Training data:  [%d] epoch,  loss: %.5f, accuracy: %.5f, precision: %.5f, auc: %.5f'%
                    (epoch, train_loss, train_accuracy, train_precision, train_auc))
            print('Valid data:  [%d] epoch,  loss: %.5f, accuracy: %.5f precision: %.5f, auc: %.5f' %
                    (epoch, valid_loss, valid_accuracy, valid_precision, valid_auc))
            torch.save(self.model.state_dict(), self.save_path)
            tmp = pd.DataFrame(learning_data)
            tmp.to_csv(self.save_path + '.csv')

        print('Finished Training')

# %% [markdown]
# ### **Define learning parameters**

# %%
project_dir = '/home/jupyter-n.artemenko/projects/spikelet_pubescence'
model_name = 'efficientnet_b1'
train_batch_size = 8
inference_batch_size = 16
epochs = 150
lr = 1e-7
wd = 1e-6
criterion = nn.BCELoss()
# criterion = FocalLoss(reduction = 'sum')
# optimizer = optim.SGD(model.get_params(), lr=1e-7, momentum=0.7, weight_decay=1e-5)

# %% [markdown]
# ### **Define model**

# %%
model = MyCNN(f'{project_dir}/models/LastChance/{epochs}_epochs_{model_name}_lr{lr}_CentCrop_wd{wd}_512x512_first_splits',
                criterion,
                lr, 
                wd)
# Out:
# {'training': True, '_parameters': OrderedDict(), '_buffers': OrderedDict(), '_non_persistent_buffers_set': set(), '_backward_hooks': OrderedDict(), '_is_full_backward_hook': None, '_forward_hooks': OrderedDict(), '_forward_pre_hooks': OrderedDict(), '_state_dict_hooks': OrderedDict(), '_load_state_dict_pre_hooks': OrderedDict(), '_modules': OrderedDict([('features', Sequential(
#   (0): ConvNormActivation(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU(inplace=True)
#   )
#   (1): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (2): ConvNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.008695652173913044, mode=row)
#     )
#   )
#   (2): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.017391304347826087, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.026086956521739136, mode=row)
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.034782608695652174, mode=row)
#     )
#   )
#   (3): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.05217391304347827, mode=row)
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.06086956521739131, mode=row)
#     )
#   )
#   (4): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.06956521739130435, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.0782608695652174, mode=row)
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.09565217391304348, mode=row)
#     )
#   )
#   (5): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#           (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.10434782608695654, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.11304347826086956, mode=row)
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.12173913043478261, mode=row)
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#     )
#   )
#   (6): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#           (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.1391304347826087, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.14782608695652175, mode=row)
#     )
#     (2): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.1565217391304348, mode=row)
#     )
#     (3): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.16521739130434784, mode=row)
#     )
#     (4): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#     )
#   )
#   (7): Sequential(
#     (0): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#           (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.1826086956521739, mode=row)
#     )
#     (1): MBConv(
#       (block): Sequential(
#         (0): ConvNormActivation(
#           (0): Conv2d(320, 1920, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (1): ConvNormActivation(
#           (0): Conv2d(1920, 1920, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1920, bias=False)
#           (1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): SiLU(inplace=True)
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1920, 80, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(80, 1920, kernel_size=(1, 1), stride=(1, 1))
#           (activation): SiLU(inplace=True)
#           (scale_activation): Sigmoid()
#         )
#         (3): ConvNormActivation(
#           (0): Conv2d(1920, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (stochastic_depth): StochasticDepth(p=0.19130434782608696, mode=row)
#     )
#   )
#   (8): ConvNormActivation(
#     (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): SiLU(inplace=True)
#   )
# )), ('avgpool', AdaptiveAvgPool2d(output_size=1)), ('classifier', Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# ))])}

# %%
from torchsummary import summary

mdl = torchvision.models.efficientnet_b1(pretrained=True)
summary(mdl, (3, 512, 512))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 1280, 16, 16]        --
# |    └─ConvNormActivation: 2-1                [-1, 32, 256, 256]        --
# |    |    └─Conv2d: 3-1                       [-1, 32, 256, 256]        864
# |    |    └─BatchNorm2d: 3-2                  [-1, 32, 256, 256]        64
# |    |    └─SiLU: 3-3                         [-1, 32, 256, 256]        --
# |    └─Sequential: 2-2                        [-1, 16, 256, 256]        --
# |    |    └─MBConv: 3-4                       [-1, 16, 256, 256]        1,448
# |    |    └─MBConv: 3-5                       [-1, 16, 256, 256]        612
# |    └─Sequential: 2-3                        [-1, 24, 128, 128]        --
# |    |    └─MBConv: 3-6                       [-1, 24, 128, 128]        6,004
# |    |    └─MBConv: 3-7                       [-1, 24, 128, 128]        10,710
# |    |    └─MBConv: 3-8                       [-1, 24, 128, 128]        10,710
# |    └─Sequential: 2-4                        [-1, 40, 64, 64]          --
# |    |    └─MBConv: 3-9                       [-1, 40, 64, 64]          15,350
# |    |    └─MBConv: 3-10                      [-1, 40, 64, 64]          31,290
# |    |    └─MBConv: 3-11                      [-1, 40, 64, 64]          31,290
# |    └─Sequential: 2-5                        [-1, 80, 32, 32]          --
# |    |    └─MBConv: 3-12                      [-1, 80, 32, 32]          37,130
# |    |    └─MBConv: 3-13                      [-1, 80, 32, 32]          102,900
# |    |    └─MBConv: 3-14                      [-1, 80, 32, 32]          102,900
# |    |    └─MBConv: 3-15                      [-1, 80, 32, 32]          102,900
# |    └─Sequential: 2-6                        [-1, 112, 32, 32]         --
# |    |    └─MBConv: 3-16                      [-1, 112, 32, 32]         126,004
# |    |    └─MBConv: 3-17                      [-1, 112, 32, 32]         208,572
# |    |    └─MBConv: 3-18                      [-1, 112, 32, 32]         208,572
# |    |    └─MBConv: 3-19                      [-1, 112, 32, 32]         208,572
# |    └─Sequential: 2-7                        [-1, 192, 16, 16]         --
# |    |    └─MBConv: 3-20                      [-1, 192, 16, 16]         262,492
# |    |    └─MBConv: 3-21                      [-1, 192, 16, 16]         587,952
# |    |    └─MBConv: 3-22                      [-1, 192, 16, 16]         587,952
# |    |    └─MBConv: 3-23                      [-1, 192, 16, 16]         587,952
# |    |    └─MBConv: 3-24                      [-1, 192, 16, 16]         587,952
# |    └─Sequential: 2-8                        [-1, 320, 16, 16]         --
# |    |    └─MBConv: 3-25                      [-1, 320, 16, 16]         717,232
# |    |    └─MBConv: 3-26                      [-1, 320, 16, 16]         1,563,600
# |    └─ConvNormActivation: 2-9                [-1, 1280, 16, 16]        --
# |    |    └─Conv2d: 3-27                      [-1, 1280, 16, 16]        409,600
# |    |    └─BatchNorm2d: 3-28                 [-1, 1280, 16, 16]        2,560
# |    |    └─SiLU: 3-29                        [-1, 1280, 16, 16]        --
# ├─AdaptiveAvgPool2d: 1-2                      [-1, 1280, 1, 1]          --
# ├─Sequential: 1-3                             [-1, 1000]                --
# |    └─Dropout: 2-10                          [-1, 1280]                --
# |    └─Linear: 2-11                           [-1, 1000]                1,281,000
# ===============================================================================================
# Total params: 7,794,184
# Trainable params: 7,794,184
# Non-trainable params: 0
# Total mult-adds (M): 189.09
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 37.01
# Params size (MB): 29.73
# Estimated Total Size (MB): 69.74
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 1280, 16, 16]        --
# |    └─ConvNormActivation: 2-1                [-1, 32, 256, 256]        --
# |    |    └─Conv2d: 3-1                       [-1, 32, 256, 256]        864
# |    |    └─BatchNorm2d: 3-2                  [-1, 32, 256, 256]        64
# |    |    └─SiLU: 3-3                         [-1, 32, 256, 256]        --
# |    └─Sequential: 2-2                        [-1, 16, 256, 256]        --
# |    |    └─MBConv: 3-4                       [-1, 16, 256, 256]        1,448
# |    |    └─MBConv: 3-5                       [-1, 16, 256, 256]        612
# |    └─Sequential: 2-3                        [-1, 24, 128, 128]        --
# |    |    └─MBConv: 3-6                       [-1, 24, 128, 128]        6,004
# |    |    └─MBConv: 3-7                       [-1, 24, 128, 128]        10,710
# |    |    └─MBConv: 3-8                       [-1, 24, 128, 128]        10,710
# |    └─Sequential: 2-4                        [-1, 40, 64, 64]          --
# |    |    └─MBConv: 3-9                       [-1, 40, 64, 64]          15,350
# |    |    └─MBConv: 3-10                      [-1, 40, 64, 64]          31,290
# |    |    └─MBConv: 3-11                      [-1, 40, 64, 64]          31,290
# |    └─Sequential: 2-5                        [-1, 80, 32, 32]          --
# |    |    └─MBConv: 3-12                      [-1, 80, 32, 32]          37,130
# |    |    └─MBConv: 3-13                      [-1, 80, 32, 32]          102,900
# |    |    └─MBConv: 3-14                      [-1, 80, 32, 32]          102,900
# |    |    └─MBConv: 3-15                      [-1, 80, 32, 32]          102,900
# |    └─Sequential: 2-6                        [-1, 112, 32, 32]         --
# |    |    └─MBConv: 3-16                      [-1, 112, 32, 32]         126,004
# |    |    └─MBConv: 3-17                      [-1, 112, 32, 32]         208,572
# |    |    └─MBConv: 3-18                      [-1, 112, 32, 32]         208,572
# |    |    └─MBConv: 3-19                      [-1, 112, 32, 32]         208,572
# |    └─Sequential: 2-7                        [-1, 192, 16, 16]         --
# |    |    └─MBConv: 3-20                      [-1, 192, 16, 16]         262,492
# |    |    └─MBConv: 3-21                      [-1, 192, 16, 16]         587,952
# |    |    └─MBConv: 3-22                      [-1, 192, 16, 16]         587,952
# |    |    └─MBConv: 3-23                      [-1, 192, 16, 16]         587,952
# |    |    └─MBConv: 3-24                      [-1, 192, 16, 16]         587,952
# |    └─Sequential: 2-8                        [-1, 320, 16, 16]         --
# |    |    └─MBConv: 3-25                      [-1, 320, 16, 16]         717,232
# |    |    └─MBConv: 3-26                      [-1, 320, 16, 16]         1,563,600
# |    └─ConvNormActivation: 2-9                [-1, 1280, 16, 16]        --
# |    |    └─Conv2d: 3-27                      [-1, 1280, 16, 16]        409,600
# |    |    └─BatchNorm2d: 3-28                 [-1, 1280, 16, 16]        2,560
# |    |    └─SiLU: 3-29                        [-1, 1280, 16, 16]        --
# ├─AdaptiveAvgPool2d: 1-2                      [-1, 1280, 1, 1]          --
# ├─Sequential: 1-3                             [-1, 1000]                --
# |    └─Dropout: 2-10                          [-1, 1280]                --
# |    └─Linear: 2-11                           [-1, 1000]                1,281,000
# ===============================================================================================
# Total params: 7,794,184
# Trainable params: 7,794,184
# Non-trainable params: 0
# Total mult-adds (M): 189.09
# ===============================================================================================
# Input size (MB): 3.00
# Forward/backward pass size (MB): 37.01
# Params size (MB): 29.73
# Estimated Total Size (MB): 69.74
# ===============================================================================================

# %% [markdown]
# ### **Train model**

# %%
model.fit(batch_sizes=(train_batch_size, inference_batch_size), epochs=epochs)
# Out:
# Epoch number: 1
# [[1449 3296]
#  [ 665 1909]]
# [[305 230]
#  [131 163]]
# Training data:  [1] epoch,  loss: 0.70923, accuracy: 0.45881, precision: 0.36676, auc: 0.52105
# Valid data:  [1] epoch,  loss: 0.69234, accuracy: 0.56454 precision: 0.41476, auc: 0.56267
# Epoch number: 2
# [[3181 1564]
#  [1363 1211]]
# [[487  48]
#  [247  47]]
# Training data:  [2] epoch,  loss: 0.67479, accuracy: 0.60008, precision: 0.43640, auc: 0.57620
# Valid data:  [2] epoch,  loss: 0.66687, accuracy: 0.64415 precision: 0.49474, auc: 0.54452
# Epoch number: 3
# [[4149  596]
#  [1806  768]]
# [[508  27]
#  [273  21]]
# Training data:  [3] epoch,  loss: 0.64798, accuracy: 0.67181, precision: 0.56305, auc: 0.62045
# Valid data:  [3] epoch,  loss: 0.65729, accuracy: 0.63812 precision: 0.43750, auc: 0.54455
# Epoch number: 4
# [[4465  280]
#  [2030  544]]
# [[534   1]
#  [288   6]]
# Training data:  [4] epoch,  loss: 0.62801, accuracy: 0.68438, precision: 0.66019, auc: 0.65570
# Valid data:  [4] epoch,  loss: 0.63635, accuracy: 0.65139 precision: 0.85714, auc: 0.63738
# Epoch number: 5
# [[4558  187]
#  [2095  479]]
# [[534   1]
#  [283  11]]
# Training data:  [5] epoch,  loss: 0.61103, accuracy: 0.68821, precision: 0.71922, auc: 0.68758
# Valid data:  [5] epoch,  loss: 0.62283, accuracy: 0.65742 precision: 0.91667, auc: 0.68889
# Epoch number: 6
# [[4581  164]
#  [2099  475]]
# [[534   1]
#  [281  13]]
# Training data:  [6] epoch,  loss: 0.59514, accuracy: 0.69080, precision: 0.74335, auc: 0.71825
# Valid data:  [6] epoch,  loss: 0.60975, accuracy: 0.65983 precision: 0.92857, auc: 0.69177
# Epoch number: 7
# [[4592  153]
#  [2055  519]]
# [[532   3]
#  [277  17]]
# Training data:  [7] epoch,  loss: 0.58190, accuracy: 0.69832, precision: 0.77232, auc: 0.73011
# Valid data:  [7] epoch,  loss: 0.59842, accuracy: 0.66224 precision: 0.85000, auc: 0.72150
# Epoch number: 8
# [[4565  180]
#  [2031  543]]
# [[534   1]
#  [280  14]]
# Training data:  [8] epoch,  loss: 0.56850, accuracy: 0.69791, precision: 0.75104, auc: 0.75631
# Valid data:  [8] epoch,  loss: 0.58951, accuracy: 0.66104 precision: 0.93333, auc: 0.75600
# Epoch number: 9
# [[4563  182]
#  [1912  662]]
# [[520  15]
#  [249  45]]
# Training data:  [9] epoch,  loss: 0.55332, accuracy: 0.71390, precision: 0.78436, auc: 0.77763
# Valid data:  [9] epoch,  loss: 0.56069, accuracy: 0.68154 precision: 0.75000, auc: 0.80206
# Epoch number: 10
# [[4527  218]
#  [1822  752]]
# [[520  15]
#  [248  46]]
# Training data:  [10] epoch,  loss: 0.54244, accuracy: 0.72127, precision: 0.77526, auc: 0.78135
# Valid data:  [10] epoch,  loss: 0.54927, accuracy: 0.68275 precision: 0.75410, auc: 0.81275
# Epoch number: 11
# [[4474  271]
#  [1715  859]]
# [[522  13]
#  [239  55]]
# Training data:  [11] epoch,  loss: 0.53090, accuracy: 0.72865, precision: 0.76018, auc: 0.79230
# Valid data:  [11] epoch,  loss: 0.54526, accuracy: 0.69602 precision: 0.80882, auc: 0.81651
# Epoch number: 12
# [[4433  312]
#  [1570 1004]]
# [[521  14]
#  [240  54]]
# Training data:  [12] epoch,  loss: 0.51355, accuracy: 0.74286, precision: 0.76292, auc: 0.80942
# Valid data:  [12] epoch,  loss: 0.53464, accuracy: 0.69361 precision: 0.79412, auc: 0.83370
# Epoch number: 13
# [[4407  338]
#  [1443 1131]]
# [[512  23]
#  [205  89]]
# Training data:  [13] epoch,  loss: 0.50046, accuracy: 0.75666, precision: 0.76991, auc: 0.81849
# Valid data:  [13] epoch,  loss: 0.51229, accuracy: 0.72497 precision: 0.79464, auc: 0.86250
# Epoch number: 14
# [[4303  442]
#  [1365 1209]]
# [[510  25]
#  [181 113]]
# Training data:  [14] epoch,  loss: 0.49567, accuracy: 0.75311, precision: 0.73228, auc: 0.81913
# Valid data:  [14] epoch,  loss: 0.50005, accuracy: 0.75151 precision: 0.81884, auc: 0.87081
# Epoch number: 15
# [[4312  433]
#  [1230 1344]]
# [[502  33]
#  [148 146]]
# Training data:  [15] epoch,  loss: 0.47131, accuracy: 0.77278, precision: 0.75633, auc: 0.84263
# Valid data:  [15] epoch,  loss: 0.49530, accuracy: 0.78166 precision: 0.81564, auc: 0.87509
# Epoch number: 16
# [[4288  457]
#  [1125 1449]]
# [[501  34]
#  [128 166]]
# Training data:  [16] epoch,  loss: 0.46572, accuracy: 0.78385, precision: 0.76023, auc: 0.84523
# Valid data:  [16] epoch,  loss: 0.48264, accuracy: 0.80458 precision: 0.83000, auc: 0.88271
# Epoch number: 17
# [[4254  491]
#  [ 954 1620]]
# [[479  56]
#  [ 82 212]]
# Training data:  [17] epoch,  loss: 0.44070, accuracy: 0.80257, precision: 0.76741, auc: 0.86508
# Valid data:  [17] epoch,  loss: 0.47712, accuracy: 0.83353 precision: 0.79104, auc: 0.89372
# Epoch number: 18
# [[4202  543]
#  [ 906 1668]]
# [[470  65]
#  [ 68 226]]
# Training data:  [18] epoch,  loss: 0.43787, accuracy: 0.80202, precision: 0.75441, auc: 0.86399
# Valid data:  [18] epoch,  loss: 0.46077, accuracy: 0.83957 precision: 0.77663, auc: 0.89796
# Epoch number: 19
# [[4183  562]
#  [ 854 1720]]
# [[445  90]
#  [ 55 239]]
# Training data:  [19] epoch,  loss: 0.42795, accuracy: 0.80653, precision: 0.75372, auc: 0.87078
# Valid data:  [19] epoch,  loss: 0.47852, accuracy: 0.82509 precision: 0.72644, auc: 0.90020
# Epoch number: 20
# [[4165  580]
#  [ 763 1811]]
# [[460  75]
#  [ 66 228]]
# Training data:  [20] epoch,  loss: 0.41522, accuracy: 0.81651, precision: 0.75742, auc: 0.87979
# Valid data:  [20] epoch,  loss: 0.45727, accuracy: 0.82992 precision: 0.75248, auc: 0.89328
# Epoch number: 21
# [[4127  618]
#  [ 717 1857]]
# [[410 125]
#  [ 47 247]]
# Training data:  [21] epoch,  loss: 0.40881, accuracy: 0.81760, precision: 0.75030, auc: 0.88256
# Valid data:  [21] epoch,  loss: 0.47438, accuracy: 0.79252 precision: 0.66398, auc: 0.89332
# Epoch number: 22
# [[4182  563]
#  [ 651 1923]]
# [[392 143]
#  [ 37 257]]
# Training data:  [22] epoch,  loss: 0.39114, accuracy: 0.83413, precision: 0.77353, auc: 0.89467
# Valid data:  [22] epoch,  loss: 0.47497, accuracy: 0.78287 precision: 0.64250, auc: 0.89903
# Epoch number: 23
# [[4101  644]
#  [ 633 1941]]
# [[421 114]
#  [ 41 253]]
# Training data:  [23] epoch,  loss: 0.39240, accuracy: 0.82552, precision: 0.75087, auc: 0.89182
# Valid data:  [23] epoch,  loss: 0.44247, accuracy: 0.81303 precision: 0.68937, auc: 0.90215
# Epoch number: 24
# [[4144  601]
#  [ 640 1934]]
# [[475  60]
#  [ 67 227]]
# Training data:  [24] epoch,  loss: 0.38725, accuracy: 0.83044, precision: 0.76292, auc: 0.89328
# Valid data:  [24] epoch,  loss: 0.39527, accuracy: 0.84680 precision: 0.79094, auc: 0.91054
# Epoch number: 25
# [[4129  616]
#  [ 566 2008]]
# [[461  74]
#  [ 53 241]]
# Training data:  [25] epoch,  loss: 0.37646, accuracy: 0.83850, precision: 0.76524, auc: 0.90100
# Valid data:  [25] epoch,  loss: 0.38987, accuracy: 0.84680 precision: 0.76508, auc: 0.91546
# Epoch number: 26
# [[4167  578]
#  [ 554 2020]]
# [[421 114]
#  [ 43 251]]
# Training data:  [26] epoch,  loss: 0.36502, accuracy: 0.84533, precision: 0.77752, auc: 0.90667
# Valid data:  [26] epoch,  loss: 0.41825, accuracy: 0.81062 precision: 0.68767, auc: 0.90972
# Epoch number: 27
# [[4181  564]
#  [ 533 2041]]
# [[446  89]
#  [ 46 248]]
# Training data:  [27] epoch,  loss: 0.35353, accuracy: 0.85012, precision: 0.78349, auc: 0.91167
# Valid data:  [27] epoch,  loss: 0.38775, accuracy: 0.83715 precision: 0.73591, auc: 0.91585
# Epoch number: 28
# [[4218  527]
#  [ 506 2068]]
# [[425 110]
#  [ 38 256]]
# Training data:  [28] epoch,  loss: 0.33987, accuracy: 0.85886, precision: 0.79692, auc: 0.91869
# Valid data:  [28] epoch,  loss: 0.37725, accuracy: 0.82147 precision: 0.69945, auc: 0.92646
# Epoch number: 29
# [[4202  543]
#  [ 524 2050]]
# [[450  85]
#  [ 37 257]]
# Training data:  [29] epoch,  loss: 0.35197, accuracy: 0.85422, precision: 0.79059, auc: 0.91073
# Valid data:  [29] epoch,  loss: 0.35189, accuracy: 0.85283 precision: 0.75146, auc: 0.93580
# Epoch number: 30
# [[4219  526]
#  [ 502 2072]]
# [[456  79]
#  [ 44 250]]
# Training data:  [30] epoch,  loss: 0.32937, accuracy: 0.85954, precision: 0.79754, auc: 0.92213
# Valid data:  [30] epoch,  loss: 0.34048, accuracy: 0.85163 precision: 0.75988, auc: 0.93198
# Epoch number: 31
# [[4229  516]
#  [ 506 2068]]
# [[449  86]
#  [ 32 262]]
# Training data:  [31] epoch,  loss: 0.33296, accuracy: 0.86036, precision: 0.80031, auc: 0.91961
# Valid data:  [31] epoch,  loss: 0.33086, accuracy: 0.85766 precision: 0.75287, auc: 0.94364
# Epoch number: 32
# [[4283  462]
#  [ 478 2096]]
# [[429 106]
#  [ 21 273]]
# Training data:  [32] epoch,  loss: 0.31860, accuracy: 0.87157, precision: 0.81939, auc: 0.92627
# Valid data:  [32] epoch,  loss: 0.34325, accuracy: 0.84680 precision: 0.72032, auc: 0.94950
# Epoch number: 33
# [[4298  447]
#  [ 482 2092]]
# [[426 109]
#  [ 21 273]]
# Training data:  [33] epoch,  loss: 0.30997, accuracy: 0.87307, precision: 0.82395, auc: 0.92792
# Valid data:  [33] epoch,  loss: 0.33751, accuracy: 0.84318 precision: 0.71466, auc: 0.95162
# Epoch number: 34
# [[4296  449]
#  [ 499 2075]]
# [[400 135]
#  [ 13 281]]
# Training data:  [34] epoch,  loss: 0.30281, accuracy: 0.87047, precision: 0.82211, auc: 0.93143
# Valid data:  [34] epoch,  loss: 0.36939, accuracy: 0.82147 precision: 0.67548, auc: 0.94439
# Epoch number: 35
# [[4313  432]
#  [ 491 2083]]
# [[410 125]
#  [  8 286]]
# Training data:  [35] epoch,  loss: 0.30967, accuracy: 0.87389, precision: 0.82823, auc: 0.92720
# Valid data:  [35] epoch,  loss: 0.34307, accuracy: 0.83957 precision: 0.69586, auc: 0.95783
# Epoch number: 36
# [[4387  358]
#  [ 486 2088]]
# [[443  92]
#  [ 25 269]]
# Training data:  [36] epoch,  loss: 0.29641, accuracy: 0.88468, precision: 0.85364, auc: 0.93322
# Valid data:  [36] epoch,  loss: 0.30094, accuracy: 0.85887 precision: 0.74515, auc: 0.94966
# Epoch number: 37
# [[4372  373]
#  [ 520 2054]]
# [[449  86]
#  [ 30 264]]
# Training data:  [37] epoch,  loss: 0.29953, accuracy: 0.87799, precision: 0.84631, auc: 0.93305
# Valid data:  [37] epoch,  loss: 0.28667, accuracy: 0.86007 precision: 0.75429, auc: 0.95067
# Epoch number: 38
# [[4350  395]
#  [ 493 2081]]
# [[402 133]
#  [  9 285]]
# Training data:  [38] epoch,  loss: 0.29059, accuracy: 0.87867, precision: 0.84047, auc: 0.93489
# Valid data:  [38] epoch,  loss: 0.36131, accuracy: 0.82871 precision: 0.68182, auc: 0.94836
# Epoch number: 39
# [[4375  370]
#  [ 509 2065]]
# [[424 111]
#  [ 11 283]]
# Training data:  [39] epoch,  loss: 0.28931, accuracy: 0.87990, precision: 0.84805, auc: 0.93446
# Valid data:  [39] epoch,  loss: 0.30426, accuracy: 0.85283 precision: 0.71827, auc: 0.96173
# Epoch number: 40
# [[4413  332]
#  [ 474 2100]]
# [[431 104]
#  [ 11 283]]
# Training data:  [40] epoch,  loss: 0.27822, accuracy: 0.88988, precision: 0.86349, auc: 0.93828
# Valid data:  [40] epoch,  loss: 0.28836, accuracy: 0.86128 precision: 0.73127, auc: 0.96172
# Epoch number: 41
# [[4411  334]
#  [ 474 2100]]
# [[461  74]
#  [ 18 276]]
# Training data:  [41] epoch,  loss: 0.27722, accuracy: 0.88960, precision: 0.86278, auc: 0.93992
# Valid data:  [41] epoch,  loss: 0.24612, accuracy: 0.88902 precision: 0.78857, auc: 0.96921
# Epoch number: 42
# [[4435  310]
#  [ 464 2110]]
# [[429 106]
#  [  9 285]]
# Training data:  [42] epoch,  loss: 0.26088, accuracy: 0.89425, precision: 0.87190, auc: 0.94490
# Valid data:  [42] epoch,  loss: 0.29529, accuracy: 0.86128 precision: 0.72890, auc: 0.96130
# Epoch number: 43
# [[4428  317]
#  [ 451 2123]]
# [[427 108]
#  [  9 285]]
# Training data:  [43] epoch,  loss: 0.27080, accuracy: 0.89507, precision: 0.87008, auc: 0.94093
# Valid data:  [43] epoch,  loss: 0.30233, accuracy: 0.85887 precision: 0.72519, auc: 0.96272
# Epoch number: 44
# [[4439  306]
#  [ 407 2167]]
# [[421 114]
#  [  8 286]]
# Training data:  [44] epoch,  loss: 0.25248, accuracy: 0.90258, precision: 0.87626, auc: 0.94889
# Valid data:  [44] epoch,  loss: 0.32683, accuracy: 0.85283 precision: 0.71500, auc: 0.95349
# Epoch number: 45
# [[4424  321]
#  [ 453 2121]]
# [[445  90]
#  [ 11 283]]
# Training data:  [45] epoch,  loss: 0.26608, accuracy: 0.89425, precision: 0.86855, auc: 0.94472
# Valid data:  [45] epoch,  loss: 0.27016, accuracy: 0.87817 precision: 0.75871, auc: 0.96404
# Epoch number: 46
# [[4437  308]
#  [ 400 2174]]
# [[466  69]
#  [ 15 279]]
# Training data:  [46] epoch,  loss: 0.24510, accuracy: 0.90327, precision: 0.87591, auc: 0.94999
# Valid data:  [46] epoch,  loss: 0.23606, accuracy: 0.89867 precision: 0.80172, auc: 0.97096
# Epoch number: 47
# [[4445  300]
#  [ 385 2189]]
# [[464  71]
#  [ 12 282]]
# Training data:  [47] epoch,  loss: 0.24091, accuracy: 0.90641, precision: 0.87947, auc: 0.95338
# Valid data:  [47] epoch,  loss: 0.23780, accuracy: 0.89988 precision: 0.79887, auc: 0.96787
# Epoch number: 48
# [[4421  324]
#  [ 411 2163]]
# [[435 100]
#  [  9 285]]
# Training data:  [48] epoch,  loss: 0.25440, accuracy: 0.89958, precision: 0.86972, auc: 0.94704
# Valid data:  [48] epoch,  loss: 0.29401, accuracy: 0.86852 precision: 0.74026, auc: 0.96020
# Epoch number: 49
# [[4442  303]
#  [ 380 2194]]
# [[462  73]
#  [ 17 277]]
# Training data:  [49] epoch,  loss: 0.24780, accuracy: 0.90668, precision: 0.87865, auc: 0.94963
# Valid data:  [49] epoch,  loss: 0.23669, accuracy: 0.89144 precision: 0.79143, auc: 0.96577
# Epoch number: 50
# [[4430  315]
#  [ 353 2221]]
# [[477  58]
#  [ 19 275]]
# Training data:  [50] epoch,  loss: 0.23660, accuracy: 0.90873, precision: 0.87579, auc: 0.95329
# Valid data:  [50] epoch,  loss: 0.21162, accuracy: 0.90712 precision: 0.82583, auc: 0.97226
# Epoch number: 51
# [[4442  303]
#  [ 369 2205]]
# [[479  56]
#  [ 12 282]]
# Training data:  [51] epoch,  loss: 0.23924, accuracy: 0.90818, precision: 0.87919, auc: 0.95390
# Valid data:  [51] epoch,  loss: 0.21324, accuracy: 0.91797 precision: 0.83432, auc: 0.97411
# Epoch number: 52
# [[4441  304]
#  [ 366 2208]]
# [[488  47]
#  [ 22 272]]
# Training data:  [52] epoch,  loss: 0.23366, accuracy: 0.90846, precision: 0.87898, auc: 0.95474
# Valid data:  [52] epoch,  loss: 0.19057, accuracy: 0.91677 precision: 0.85266, auc: 0.97712
# Epoch number: 53
# [[4449  296]
#  [ 362 2212]]
# [[465  70]
#  [  9 285]]
# Training data:  [53] epoch,  loss: 0.22848, accuracy: 0.91010, precision: 0.88198, auc: 0.95751
# Valid data:  [53] epoch,  loss: 0.22755, accuracy: 0.90470 precision: 0.80282, auc: 0.97411
# Epoch number: 54
# [[4435  310]
#  [ 335 2239]]
# [[482  53]
#  [ 12 282]]
# Training data:  [54] epoch,  loss: 0.22970, accuracy: 0.91187, precision: 0.87838, auc: 0.95628
# Valid data:  [54] epoch,  loss: 0.19634, accuracy: 0.92159 precision: 0.84179, auc: 0.97661
# Epoch number: 55
# [[4425  320]
#  [ 313 2261]]
# [[479  56]
#  [ 11 283]]
# Training data:  [55] epoch,  loss: 0.22117, accuracy: 0.91351, precision: 0.87602, auc: 0.96055
# Valid data:  [55] epoch,  loss: 0.20274, accuracy: 0.91918 precision: 0.83481, auc: 0.97662
# Epoch number: 56
# [[4461  284]
#  [ 317 2257]]
# [[477  58]
#  [ 13 281]]
# Training data:  [56] epoch,  loss: 0.21777, accuracy: 0.91788, precision: 0.88823, auc: 0.96182
# Valid data:  [56] epoch,  loss: 0.20129, accuracy: 0.91435 precision: 0.82891, auc: 0.97561
# Epoch number: 57
# [[4418  327]
#  [ 326 2248]]
# [[489  46]
#  [ 15 279]]
# Training data:  [57] epoch,  loss: 0.22493, accuracy: 0.91078, precision: 0.87301, auc: 0.95811
# Valid data:  [57] epoch,  loss: 0.18144, accuracy: 0.92642 precision: 0.85846, auc: 0.98240
# Epoch number: 58
# [[4443  302]
#  [ 300 2274]]
# [[458  77]
#  [  9 285]]
# Training data:  [58] epoch,  loss: 0.20941, accuracy: 0.91775, precision: 0.88276, auc: 0.96331
# Valid data:  [58] epoch,  loss: 0.23772, accuracy: 0.89626 precision: 0.78729, auc: 0.97442
# Epoch number: 59
# [[4479  266]
#  [ 314 2260]]
# [[455  80]
#  [  5 289]]
# Training data:  [59] epoch,  loss: 0.21323, accuracy: 0.92075, precision: 0.89470, auc: 0.96254
# Valid data:  [59] epoch,  loss: 0.24406, accuracy: 0.89747 precision: 0.78320, auc: 0.97620
# Epoch number: 60
# [[4475  270]
#  [ 308 2266]]
# [[474  61]
#  [  7 287]]
# Training data:  [60] epoch,  loss: 0.21169, accuracy: 0.92103, precision: 0.89353, auc: 0.96249
# Valid data:  [60] epoch,  loss: 0.21303, accuracy: 0.91797 precision: 0.82471, auc: 0.97860
# Epoch number: 61
# [[4489  256]
#  [ 301 2273]]
# [[485  50]
#  [ 16 278]]
# Training data:  [61] epoch,  loss: 0.20254, accuracy: 0.92390, precision: 0.89877, auc: 0.96590
# Valid data:  [61] epoch,  loss: 0.19306, accuracy: 0.92039 precision: 0.84756, auc: 0.97818
# Epoch number: 62
# [[4492  253]
#  [ 283 2291]]
# [[451  84]
#  [  2 292]]
# Training data:  [62] epoch,  loss: 0.20229, accuracy: 0.92677, precision: 0.90055, auc: 0.96476
# Valid data:  [62] epoch,  loss: 0.25316, accuracy: 0.89626 precision: 0.77660, auc: 0.97848
# Epoch number: 63
# [[4454  291]
#  [ 293 2281]]
# [[459  76]
#  [  3 291]]
# Training data:  [63] epoch,  loss: 0.20608, accuracy: 0.92021, precision: 0.88686, auc: 0.96383
# Valid data:  [63] epoch,  loss: 0.24664, accuracy: 0.90470 precision: 0.79292, auc: 0.97418
# Epoch number: 64
# [[4486  259]
#  [ 293 2281]]
# [[472  63]
#  [  8 286]]
# Training data:  [64] epoch,  loss: 0.20175, accuracy: 0.92458, precision: 0.89803, auc: 0.96359
# Valid data:  [64] epoch,  loss: 0.21120, accuracy: 0.91435 precision: 0.81948, auc: 0.97548
# Epoch number: 65
# [[4470  275]
#  [ 274 2300]]
# [[476  59]
#  [ 11 283]]
# Training data:  [65] epoch,  loss: 0.19518, accuracy: 0.92499, precision: 0.89320, auc: 0.96821
# Valid data:  [65] epoch,  loss: 0.19739, accuracy: 0.91556 precision: 0.82749, auc: 0.98004
# Epoch number: 66
# [[4503  242]
#  [ 282 2292]]
# [[499  36]
#  [ 15 279]]
# Training data:  [66] epoch,  loss: 0.19007, accuracy: 0.92841, precision: 0.90450, auc: 0.96875
# Valid data:  [66] epoch,  loss: 0.14564, accuracy: 0.93848 precision: 0.88571, auc: 0.98718
# Epoch number: 67
# [[4493  252]
#  [ 263 2311]]
# [[460  75]
#  [  3 291]]
# Training data:  [67] epoch,  loss: 0.18834, accuracy: 0.92964, precision: 0.90168, auc: 0.96982
# Valid data:  [67] epoch,  loss: 0.23006, accuracy: 0.90591 precision: 0.79508, auc: 0.97951
# Epoch number: 68
# [[4497  248]
#  [ 248 2326]]
# [[473  62]
#  [  3 291]]
# Training data:  [68] epoch,  loss: 0.18162, accuracy: 0.93223, precision: 0.90365, auc: 0.97040
# Valid data:  [68] epoch,  loss: 0.19370, accuracy: 0.92159 precision: 0.82436, auc: 0.98352
# Epoch number: 69
# [[4517  228]
#  [ 300 2274]]
# [[486  49]
#  [ 11 283]]
# Training data:  [69] epoch,  loss: 0.18899, accuracy: 0.92786, precision: 0.90887, auc: 0.96935
# Valid data:  [69] epoch,  loss: 0.16603, accuracy: 0.92762 precision: 0.85241, auc: 0.98309
# Epoch number: 70
# [[4521  224]
#  [ 292 2282]]
# [[482  53]
#  [ 11 283]]
# Training data:  [70] epoch,  loss: 0.18707, accuracy: 0.92950, precision: 0.91061, auc: 0.97034
# Valid data:  [70] epoch,  loss: 0.19441, accuracy: 0.92280 precision: 0.84226, auc: 0.97954
# Epoch number: 71
# [[4505  240]
#  [ 254 2320]]
# [[489  46]
#  [  9 285]]
# Training data:  [71] epoch,  loss: 0.18218, accuracy: 0.93250, precision: 0.90625, auc: 0.97165
# Valid data:  [71] epoch,  loss: 0.16511, accuracy: 0.93366 precision: 0.86103, auc: 0.98443
# Epoch number: 72
# [[4499  246]
#  [ 261 2313]]
# [[476  59]
#  [ 15 279]]
# Training data:  [72] epoch,  loss: 0.18336, accuracy: 0.93073, precision: 0.90387, auc: 0.97056
# Valid data:  [72] epoch,  loss: 0.19982, accuracy: 0.91074 precision: 0.82544, auc: 0.97521
# Epoch number: 73
# [[4541  204]
#  [ 269 2305]]
# [[474  61]
#  [ 14 280]]
# Training data:  [73] epoch,  loss: 0.17937, accuracy: 0.93537, precision: 0.91869, auc: 0.96941
# Valid data:  [73] epoch,  loss: 0.21253, accuracy: 0.90953 precision: 0.82111, auc: 0.97499
# Epoch number: 74
# [[4535  210]
#  [ 270 2304]]
# [[475  60]
#  [  6 288]]
# Training data:  [74] epoch,  loss: 0.17923, accuracy: 0.93442, precision: 0.91647, auc: 0.97136
# Valid data:  [74] epoch,  loss: 0.18828, accuracy: 0.92039 precision: 0.82759, auc: 0.98451
# Epoch number: 75
# [[4543  202]
#  [ 235 2339]]
# [[483  52]
#  [ 13 281]]
# Training data:  [75] epoch,  loss: 0.15945, accuracy: 0.94029, precision: 0.92050, auc: 0.97864
# Valid data:  [75] epoch,  loss: 0.18196, accuracy: 0.92159 precision: 0.84384, auc: 0.97994
# Epoch number: 76
# [[4545  200]
#  [ 237 2337]]
# [[476  59]
#  [  7 287]]
# Training data:  [76] epoch,  loss: 0.16453, accuracy: 0.94029, precision: 0.92117, auc: 0.97511
# Valid data:  [76] epoch,  loss: 0.18320, accuracy: 0.92039 precision: 0.82948, auc: 0.98575
# Epoch number: 77
# [[4546  199]
#  [ 251 2323]]
# [[467  68]
#  [  6 288]]
# Training data:  [77] epoch,  loss: 0.16555, accuracy: 0.93852, precision: 0.92109, auc: 0.97468
# Valid data:  [77] epoch,  loss: 0.21262, accuracy: 0.91074 precision: 0.80899, auc: 0.97791
# Epoch number: 78
# [[4536  209]
#  [ 237 2337]]
# [[474  61]
#  [  6 288]]
# Training data:  [78] epoch,  loss: 0.16426, accuracy: 0.93906, precision: 0.91791, auc: 0.97686
# Valid data:  [78] epoch,  loss: 0.20864, accuracy: 0.91918 precision: 0.82521, auc: 0.97870
# Epoch number: 79
# [[4532  213]
#  [ 230 2344]]
# [[466  69]
#  [  7 287]]
# Training data:  [79] epoch,  loss: 0.16109, accuracy: 0.93947, precision: 0.91670, auc: 0.97573
# Valid data:  [79] epoch,  loss: 0.21620, accuracy: 0.90832 precision: 0.80618, auc: 0.97707
# Epoch number: 80
# [[4547  198]
#  [ 215 2359]]
# [[475  60]
#  [  6 288]]
# Training data:  [80] epoch,  loss: 0.15670, accuracy: 0.94357, precision: 0.92257, auc: 0.97670
# Valid data:  [80] epoch,  loss: 0.19618, accuracy: 0.92039 precision: 0.82759, auc: 0.98097
# Epoch number: 81
# [[4550  195]
#  [ 241 2333]]
# [[444  91]
#  [  3 291]]
# Training data:  [81] epoch,  loss: 0.16199, accuracy: 0.94043, precision: 0.92286, auc: 0.97580
# Valid data:  [81] epoch,  loss: 0.26585, accuracy: 0.88661 precision: 0.76178, auc: 0.97340
# Epoch number: 82
# [[4525  220]
#  [ 215 2359]]
# [[485  50]
#  [  8 286]]
# Training data:  [82] epoch,  loss: 0.15639, accuracy: 0.94057, precision: 0.91470, auc: 0.97845
# Valid data:  [82] epoch,  loss: 0.17423, accuracy: 0.93004 precision: 0.85119, auc: 0.98363
# Epoch number: 83
# [[4560  185]
#  [ 212 2362]]
# [[501  34]
#  [ 18 276]]
# Training data:  [83] epoch,  loss: 0.15391, accuracy: 0.94576, precision: 0.92737, auc: 0.97800
# Valid data:  [83] epoch,  loss: 0.15985, accuracy: 0.93727 precision: 0.89032, auc: 0.98123
# Epoch number: 84
# [[4547  198]
#  [ 200 2374]]
# [[484  51]
#  [ 10 284]]
# Training data:  [84] epoch,  loss: 0.15441, accuracy: 0.94562, precision: 0.92302, auc: 0.97760
# Valid data:  [84] epoch,  loss: 0.18007, accuracy: 0.92642 precision: 0.84776, auc: 0.98109
# Epoch number: 85
# [[4547  198]
#  [ 228 2346]]
# [[452  83]
#  [  5 289]]
# Training data:  [85] epoch,  loss: 0.15489, accuracy: 0.94180, precision: 0.92217, auc: 0.97863
# Valid data:  [85] epoch,  loss: 0.21743, accuracy: 0.89385 precision: 0.77688, auc: 0.98255
# Epoch number: 86
# [[4556  189]
#  [ 199 2375]]
# [[461  74]
#  [  8 286]]
# Training data:  [86] epoch,  loss: 0.14672, accuracy: 0.94699, precision: 0.92629, auc: 0.98074
# Valid data:  [86] epoch,  loss: 0.20285, accuracy: 0.90109 precision: 0.79444, auc: 0.98325
# Epoch number: 87
# [[4569  176]
#  [ 205 2369]]
# [[484  51]
#  [ 12 282]]
# Training data:  [87] epoch,  loss: 0.14879, accuracy: 0.94794, precision: 0.93084, auc: 0.97830
# Valid data:  [87] epoch,  loss: 0.17195, accuracy: 0.92400 precision: 0.84685, auc: 0.98333
# Epoch number: 88
# [[4568  177]
#  [ 203 2371]]
# [[479  56]
#  [ 10 284]]
# Training data:  [88] epoch,  loss: 0.14804, accuracy: 0.94808, precision: 0.93053, auc: 0.97849
# Valid data:  [88] epoch,  loss: 0.18492, accuracy: 0.92039 precision: 0.83529, auc: 0.98143
# Epoch number: 89
# [[4551  194]
#  [ 209 2365]]
# [[485  50]
#  [ 17 277]]
# Training data:  [89] epoch,  loss: 0.14800, accuracy: 0.94494, precision: 0.92419, auc: 0.97937
# Valid data:  [89] epoch,  loss: 0.18488, accuracy: 0.91918 precision: 0.84709, auc: 0.97762
# Epoch number: 90
# [[4564  181]
#  [ 201 2373]]
# [[473  62]
#  [ 10 284]]
# Training data:  [90] epoch,  loss: 0.14081, accuracy: 0.94781, precision: 0.92913, auc: 0.98061
# Valid data:  [90] epoch,  loss: 0.19548, accuracy: 0.91315 precision: 0.82081, auc: 0.98021
# Epoch number: 91
# [[4588  157]
#  [ 184 2390]]
# [[474  61]
#  [ 11 283]]
# Training data:  [91] epoch,  loss: 0.13849, accuracy: 0.95341, precision: 0.93836, auc: 0.98094
# Valid data:  [91] epoch,  loss: 0.18775, accuracy: 0.91315 precision: 0.82267, auc: 0.97999
# Epoch number: 92
# [[4570  175]
#  [ 165 2409]]
# [[458  77]
#  [  8 286]]
# Training data:  [92] epoch,  loss: 0.12588, accuracy: 0.95355, precision: 0.93228, auc: 0.98564
# Valid data:  [92] epoch,  loss: 0.21134, accuracy: 0.89747 precision: 0.78788, auc: 0.98148
# Epoch number: 93
# [[4568  177]
#  [ 187 2387]]
# [[451  84]
#  [  8 286]]
# Training data:  [93] epoch,  loss: 0.14050, accuracy: 0.95027, precision: 0.93097, auc: 0.98151
# Valid data:  [93] epoch,  loss: 0.23558, accuracy: 0.88902 precision: 0.77297, auc: 0.98097
# Epoch number: 94
# [[4566  179]
#  [ 196 2378]]
# [[429 106]
#  [  6 288]]
# Training data:  [94] epoch,  loss: 0.14234, accuracy: 0.94876, precision: 0.93000, auc: 0.97961
# Valid data:  [94] epoch,  loss: 0.26705, accuracy: 0.86490 precision: 0.73096, auc: 0.97700
# Epoch number: 95
# [[4574  171]
#  [ 170 2404]]
# [[469  66]
#  [ 14 280]]
# Training data:  [95] epoch,  loss: 0.13029, accuracy: 0.95341, precision: 0.93359, auc: 0.98309
# Valid data:  [95] epoch,  loss: 0.21134, accuracy: 0.90350 precision: 0.80925, auc: 0.97452
# Epoch number: 96
# [[4574  171]
#  [ 179 2395]]
# [[450  85]
#  [  7 287]]
# Training data:  [96] epoch,  loss: 0.12837, accuracy: 0.95218, precision: 0.93336, auc: 0.98458
# Valid data:  [96] epoch,  loss: 0.23541, accuracy: 0.88902 precision: 0.77151, auc: 0.97680
# Epoch number: 97
# [[4584  161]
#  [ 169 2405]]
# [[429 106]
#  [  6 288]]
# Training data:  [97] epoch,  loss: 0.13192, accuracy: 0.95491, precision: 0.93726, auc: 0.98374
# Valid data:  [97] epoch,  loss: 0.27827, accuracy: 0.86490 precision: 0.73096, auc: 0.97389
# Epoch number: 98
# [[4586  159]
#  [ 179 2395]]
# [[455  80]
#  [  9 285]]
# Training data:  [98] epoch,  loss: 0.12827, accuracy: 0.95382, precision: 0.93774, auc: 0.98330
# Valid data:  [98] epoch,  loss: 0.22503, accuracy: 0.89264 precision: 0.78082, auc: 0.97902
# Epoch number: 99
# [[4613  132]
#  [ 140 2434]]
# [[486  49]
#  [ 14 280]]
# Training data:  [99] epoch,  loss: 0.11484, accuracy: 0.96284, precision: 0.94856, auc: 0.98615
# Valid data:  [99] epoch,  loss: 0.17778, accuracy: 0.92400 precision: 0.85106, auc: 0.98060
# Epoch number: 100
# [[4606  139]
#  [ 149 2425]]
# [[461  74]
#  [ 11 283]]
# Training data:  [100] epoch,  loss: 0.11522, accuracy: 0.96065, precision: 0.94579, auc: 0.98664
# Valid data:  [100] epoch,  loss: 0.21507, accuracy: 0.89747 precision: 0.79272, auc: 0.97925
# Epoch number: 101
# [[4623  122]
#  [ 146 2428]]
# [[437  98]
#  [  6 288]]
# Training data:  [101] epoch,  loss: 0.11069, accuracy: 0.96338, precision: 0.95216, auc: 0.98805
# Valid data:  [101] epoch,  loss: 0.26793, accuracy: 0.87455 precision: 0.74611, auc: 0.97365
# Epoch number: 102
# [[4591  154]
#  [ 167 2407]]
# [[439  96]
#  [  8 286]]
# Training data:  [102] epoch,  loss: 0.12019, accuracy: 0.95614, precision: 0.93987, auc: 0.98459
# Valid data:  [102] epoch,  loss: 0.24864, accuracy: 0.87455 precision: 0.74869, auc: 0.97730
# Epoch number: 103
# [[4619  126]
#  [ 159 2415]]
# [[464  71]
#  [  8 286]]
# Training data:  [103] epoch,  loss: 0.11769, accuracy: 0.96106, precision: 0.95041, auc: 0.98671
# Valid data:  [103] epoch,  loss: 0.20885, accuracy: 0.90470 precision: 0.80112, auc: 0.98120
# Epoch number: 104
# [[4604  141]
#  [ 154 2420]]
# [[454  81]
#  [  9 285]]
# Training data:  [104] epoch,  loss: 0.12521, accuracy: 0.95969, precision: 0.94494, auc: 0.98469
# Valid data:  [104] epoch,  loss: 0.23858, accuracy: 0.89144 precision: 0.77869, auc: 0.97928
# Epoch number: 105
# [[4603  142]
#  [ 142 2432]]
# [[452  83]
#  [  7 287]]
# Training data:  [105] epoch,  loss: 0.11427, accuracy: 0.96120, precision: 0.94483, auc: 0.98750
# Valid data:  [105] epoch,  loss: 0.24632, accuracy: 0.89144 precision: 0.77568, auc: 0.97546
# Epoch number: 106
# [[4605  140]
#  [ 145 2429]]
# [[459  76]
#  [  8 286]]
# Training data:  [106] epoch,  loss: 0.11103, accuracy: 0.96106, precision: 0.94550, auc: 0.98726
# Valid data:  [106] epoch,  loss: 0.21987, accuracy: 0.89867 precision: 0.79006, auc: 0.98325
# Epoch number: 107
# [[4623  122]
#  [ 143 2431]]
# [[458  77]
#  [  9 285]]
# Training data:  [107] epoch,  loss: 0.11122, accuracy: 0.96379, precision: 0.95221, auc: 0.98666
# Valid data:  [107] epoch,  loss: 0.22902, accuracy: 0.89626 precision: 0.78729, auc: 0.97921
# Epoch number: 108
# [[4618  127]
#  [ 133 2441]]
# [[471  64]
#  [ 11 283]]
# Training data:  [108] epoch,  loss: 0.10207, accuracy: 0.96448, precision: 0.95055, auc: 0.98915
# Valid data:  [108] epoch,  loss: 0.20771, accuracy: 0.90953 precision: 0.81556, auc: 0.97844
# Epoch number: 109
# [[4619  126]
#  [ 136 2438]]
# [[474  61]
#  [ 10 284]]
# Training data:  [109] epoch,  loss: 0.10890, accuracy: 0.96420, precision: 0.95086, auc: 0.98702
# Valid data:  [109] epoch,  loss: 0.20740, accuracy: 0.91435 precision: 0.82319, auc: 0.97752
# Epoch number: 110
# [[4636  109]
#  [ 152 2422]]
# [[454  81]
#  [  9 285]]
# Training data:  [110] epoch,  loss: 0.10891, accuracy: 0.96434, precision: 0.95693, auc: 0.98726
# Valid data:  [110] epoch,  loss: 0.24298, accuracy: 0.89144 precision: 0.77869, auc: 0.97463
# Epoch number: 111
# [[4634  111]
#  [ 137 2437]]
# [[481  54]
#  [ 14 280]]
# Training data:  [111] epoch,  loss: 0.10206, accuracy: 0.96612, precision: 0.95644, auc: 0.98796
# Valid data:  [111] epoch,  loss: 0.19256, accuracy: 0.91797 precision: 0.83832, auc: 0.98091
# Epoch number: 112
# [[4623  122]
#  [ 135 2439]]
# [[476  59]
#  [  9 285]]
# Training data:  [112] epoch,  loss: 0.10541, accuracy: 0.96489, precision: 0.95236, auc: 0.98803
# Valid data:  [112] epoch,  loss: 0.20167, accuracy: 0.91797 precision: 0.82849, auc: 0.97687
# Epoch number: 113
# [[4626  119]
#  [ 134 2440]]
# [[466  69]
#  [  8 286]]
# Training data:  [113] epoch,  loss: 0.10100, accuracy: 0.96543, precision: 0.95350, auc: 0.98920
# Valid data:  [113] epoch,  loss: 0.21629, accuracy: 0.90712 precision: 0.80563, auc: 0.97950
# Epoch number: 114
# [[4622  123]
#  [ 139 2435]]
# [[477  58]
#  [ 13 281]]
# Training data:  [114] epoch,  loss: 0.10812, accuracy: 0.96420, precision: 0.95192, auc: 0.98646
# Valid data:  [114] epoch,  loss: 0.19826, accuracy: 0.91435 precision: 0.82891, auc: 0.97799
# Epoch number: 115
# [[4637  108]
#  [ 133 2441]]
# [[485  50]
#  [ 15 279]]
# Training data:  [115] epoch,  loss: 0.10160, accuracy: 0.96707, precision: 0.95763, auc: 0.98878
# Valid data:  [115] epoch,  loss: 0.18136, accuracy: 0.92159 precision: 0.84802, auc: 0.98233
# Epoch number: 116
# [[4636  109]
#  [ 138 2436]]
# [[486  49]
#  [ 14 280]]
# Training data:  [116] epoch,  loss: 0.09496, accuracy: 0.96625, precision: 0.95717, auc: 0.98959
# Valid data:  [116] epoch,  loss: 0.17385, accuracy: 0.92400 precision: 0.85106, auc: 0.98055
# Epoch number: 117
# [[4647   98]
#  [ 136 2438]]
# [[462  73]
#  [ 11 283]]
# Training data:  [117] epoch,  loss: 0.09821, accuracy: 0.96803, precision: 0.96136, auc: 0.98885
# Valid data:  [117] epoch,  loss: 0.22117, accuracy: 0.89867 precision: 0.79494, auc: 0.97016
# Epoch number: 118
# [[4633  112]
#  [ 114 2460]]
# [[474  61]
#  [  9 285]]
# Training data:  [118] epoch,  loss: 0.09622, accuracy: 0.96912, precision: 0.95645, auc: 0.98997
# Valid data:  [118] epoch,  loss: 0.19859, accuracy: 0.91556 precision: 0.82370, auc: 0.97594
# Epoch number: 119
# [[4631  114]
#  [ 129 2445]]
# [[503  32]
#  [ 13 281]]
# Training data:  [119] epoch,  loss: 0.09159, accuracy: 0.96680, precision: 0.95545, auc: 0.99198
# Valid data:  [119] epoch,  loss: 0.14948, accuracy: 0.94572 precision: 0.89776, auc: 0.98410
# Epoch number: 120
# [[4629  116]
#  [ 126 2448]]
# [[477  58]
#  [  8 286]]
# Training data:  [120] epoch,  loss: 0.09864, accuracy: 0.96694, precision: 0.95476, auc: 0.98844
# Valid data:  [120] epoch,  loss: 0.19997, accuracy: 0.92039 precision: 0.83140, auc: 0.97768
# Epoch number: 121
# [[4662   83]
#  [ 113 2461]]
# [[483  52]
#  [ 13 281]]
# Training data:  [121] epoch,  loss: 0.09007, accuracy: 0.97322, precision: 0.96737, auc: 0.99097
# Valid data:  [121] epoch,  loss: 0.18352, accuracy: 0.92159 precision: 0.84384, auc: 0.97584
# Epoch number: 122
# [[4632  113]
#  [ 119 2455]]
# [[485  50]
#  [ 12 282]]
# Training data:  [122] epoch,  loss: 0.09587, accuracy: 0.96830, precision: 0.95600, auc: 0.98867
# Valid data:  [122] epoch,  loss: 0.18982, accuracy: 0.92521 precision: 0.84940, auc: 0.97588
# Epoch number: 123
# [[4649   96]
#  [ 129 2445]]
# [[500  35]
#  [ 17 277]]
# Training data:  [123] epoch,  loss: 0.08840, accuracy: 0.96926, precision: 0.96222, auc: 0.99107
# Valid data:  [123] epoch,  loss: 0.16634, accuracy: 0.93727 precision: 0.88782, auc: 0.97786
# Epoch number: 124
# [[4647   98]
#  [ 118 2456]]
# [[479  56]
#  [ 11 283]]
# Training data:  [124] epoch,  loss: 0.08635, accuracy: 0.97049, precision: 0.96163, auc: 0.99161
# Valid data:  [124] epoch,  loss: 0.19370, accuracy: 0.91918 precision: 0.83481, auc: 0.97477
# Epoch number: 125
# [[4640  105]
#  [ 125 2449]]
# [[486  49]
#  [ 12 282]]
# Training data:  [125] epoch,  loss: 0.09205, accuracy: 0.96857, precision: 0.95889, auc: 0.99053
# Valid data:  [125] epoch,  loss: 0.18288, accuracy: 0.92642 precision: 0.85196, auc: 0.97725
# Epoch number: 126
# [[4646   99]
#  [ 104 2470]]
# [[479  56]
#  [ 12 282]]
# Training data:  [126] epoch,  loss: 0.08587, accuracy: 0.97226, precision: 0.96146, auc: 0.99102
# Valid data:  [126] epoch,  loss: 0.18807, accuracy: 0.91797 precision: 0.83432, auc: 0.97591
# Epoch number: 127
# [[4661   84]
#  [  88 2486]]
# [[462  73]
#  [  8 286]]
# Training data:  [127] epoch,  loss: 0.07663, accuracy: 0.97650, precision: 0.96732, auc: 0.99285
# Valid data:  [127] epoch,  loss: 0.22793, accuracy: 0.90229 precision: 0.79666, auc: 0.97388
# Epoch number: 128
# [[4667   78]
#  [ 109 2465]]
# [[465  70]
#  [  8 286]]
# Training data:  [128] epoch,  loss: 0.07761, accuracy: 0.97445, precision: 0.96933, auc: 0.99199
# Valid data:  [128] epoch,  loss: 0.20322, accuracy: 0.90591 precision: 0.80337, auc: 0.97529
# Epoch number: 129
# [[4665   80]
#  [ 121 2453]]
# [[509  26]
#  [ 18 276]]
# Training data:  [129] epoch,  loss: 0.08249, accuracy: 0.97254, precision: 0.96842, auc: 0.99154
# Valid data:  [129] epoch,  loss: 0.15095, accuracy: 0.94692 precision: 0.91391, auc: 0.97726
# Epoch number: 130
# [[4659   86]
#  [ 107 2467]]
# [[480  55]
#  [ 11 283]]
# Training data:  [130] epoch,  loss: 0.08033, accuracy: 0.97363, precision: 0.96631, auc: 0.99110
# Valid data:  [130] epoch,  loss: 0.18824, accuracy: 0.92039 precision: 0.83728, auc: 0.97750
# Epoch number: 131
# [[4657   88]
#  [ 118 2456]]
# [[480  55]
#  [ 11 283]]
# Training data:  [131] epoch,  loss: 0.08282, accuracy: 0.97185, precision: 0.96541, auc: 0.99007
# Valid data:  [131] epoch,  loss: 0.19120, accuracy: 0.92039 precision: 0.83728, auc: 0.97464
# Epoch number: 132
# [[4655   90]
#  [ 111 2463]]
# [[495  40]
#  [ 17 277]]
# Training data:  [132] epoch,  loss: 0.08256, accuracy: 0.97254, precision: 0.96475, auc: 0.99044
# Valid data:  [132] epoch,  loss: 0.16193, accuracy: 0.93124 precision: 0.87382, auc: 0.97704
# Epoch number: 133
# [[4641  104]
#  [  87 2487]]
# [[497  38]
#  [ 16 278]]
# Training data:  [133] epoch,  loss: 0.07897, accuracy: 0.97390, precision: 0.95986, auc: 0.99243
# Valid data:  [133] epoch,  loss: 0.16120, accuracy: 0.93486 precision: 0.87975, auc: 0.97964
# Epoch number: 134
# [[4669   76]
#  [  93 2481]]
# [[495  40]
#  [ 16 278]]
# Training data:  [134] epoch,  loss: 0.07262, accuracy: 0.97691, precision: 0.97028, auc: 0.99380
# Valid data:  [134] epoch,  loss: 0.16274, accuracy: 0.93245 precision: 0.87421, auc: 0.98105
# Epoch number: 135
# [[4658   87]
#  [ 111 2463]]
# [[503  32]
#  [ 18 276]]
# Training data:  [135] epoch,  loss: 0.07388, accuracy: 0.97295, precision: 0.96588, auc: 0.99272
# Valid data:  [135] epoch,  loss: 0.14460, accuracy: 0.93969 precision: 0.89610, auc: 0.98158
# Epoch number: 136
# [[4655   90]
#  [  98 2476]]
# [[489  46]
#  [ 12 282]]
# Training data:  [136] epoch,  loss: 0.07380, accuracy: 0.97431, precision: 0.96493, auc: 0.99298
# Valid data:  [136] epoch,  loss: 0.17109, accuracy: 0.93004 precision: 0.85976, auc: 0.97821
# Epoch number: 137
# [[4670   75]
#  [ 109 2465]]
# [[498  37]
#  [ 16 278]]
# Training data:  [137] epoch,  loss: 0.06969, accuracy: 0.97486, precision: 0.97047, auc: 0.99339
# Valid data:  [137] epoch,  loss: 0.15939, accuracy: 0.93607 precision: 0.88254, auc: 0.97856
# Epoch number: 138
# [[4663   82]
#  [ 114 2460]]
# [[501  34]
#  [ 18 276]]
# Training data:  [138] epoch,  loss: 0.07712, accuracy: 0.97322, precision: 0.96774, auc: 0.99169
# Valid data:  [138] epoch,  loss: 0.14920, accuracy: 0.93727 precision: 0.89032, auc: 0.98080
# Epoch number: 139
# [[4662   83]
#  [  82 2492]]
# [[499  36]
#  [ 17 277]]
# Training data:  [139] epoch,  loss: 0.06236, accuracy: 0.97746, precision: 0.96777, auc: 0.99537
# Valid data:  [139] epoch,  loss: 0.15906, accuracy: 0.93607 precision: 0.88498, auc: 0.97746
# Epoch number: 140
# [[4671   74]
#  [  88 2486]]
# [[503  32]
#  [ 17 277]]
# Training data:  [140] epoch,  loss: 0.06618, accuracy: 0.97787, precision: 0.97109, auc: 0.99403
# Valid data:  [140] epoch,  loss: 0.15764, accuracy: 0.94089 precision: 0.89644, auc: 0.97483
# Epoch number: 141
# [[4676   69]
#  [ 100 2474]]
# [[505  30]
#  [ 16 278]]
# Training data:  [141] epoch,  loss: 0.06498, accuracy: 0.97691, precision: 0.97287, auc: 0.99371
# Valid data:  [141] epoch,  loss: 0.14478, accuracy: 0.94451 precision: 0.90260, auc: 0.98265
# Epoch number: 142
# [[4669   76]
#  [  96 2478]]
# [[512  23]
#  [ 20 274]]
# Training data:  [142] epoch,  loss: 0.06738, accuracy: 0.97650, precision: 0.97024, auc: 0.99389
# Valid data:  [142] epoch,  loss: 0.13962, accuracy: 0.94813 precision: 0.92256, auc: 0.97717
# Epoch number: 143
# [[4679   66]
#  [  98 2476]]
# [[514  21]
#  [ 21 273]]
# Training data:  [143] epoch,  loss: 0.06454, accuracy: 0.97759, precision: 0.97404, auc: 0.99465
# Valid data:  [143] epoch,  loss: 0.13773, accuracy: 0.94934 precision: 0.92857, auc: 0.97583
# Epoch number: 144
# [[4678   67]
#  [  91 2483]]
# [[503  32]
#  [ 14 280]]
# Training data:  [144] epoch,  loss: 0.06810, accuracy: 0.97841, precision: 0.97373, auc: 0.99279
# Valid data:  [144] epoch,  loss: 0.14828, accuracy: 0.94451 precision: 0.89744, auc: 0.98106
# Epoch number: 145
# [[4692   53]
#  [  83 2491]]
# [[506  29]
#  [ 19 275]]
# Training data:  [145] epoch,  loss: 0.05600, accuracy: 0.98142, precision: 0.97917, auc: 0.99548
# Valid data:  [145] epoch,  loss: 0.14231, accuracy: 0.94210 precision: 0.90461, auc: 0.98137
# Epoch number: 146
# [[4673   72]
#  [  73 2501]]
# [[494  41]
#  [ 13 281]]
# Training data:  [146] epoch,  loss: 0.06081, accuracy: 0.98019, precision: 0.97202, auc: 0.99479
# Valid data:  [146] epoch,  loss: 0.15820, accuracy: 0.93486 precision: 0.87267, auc: 0.97909
# Epoch number: 147
# [[4677   68]
#  [  82 2492]]
# [[502  33]
#  [ 14 280]]
# Training data:  [147] epoch,  loss: 0.06098, accuracy: 0.97951, precision: 0.97344, auc: 0.99452
# Valid data:  [147] epoch,  loss: 0.13580, accuracy: 0.94331 precision: 0.89457, auc: 0.98295
# Epoch number: 148
# [[4693   52]
#  [  82 2492]]
# [[495  40]
#  [ 13 281]]
# Training data:  [148] epoch,  loss: 0.05555, accuracy: 0.98169, precision: 0.97956, auc: 0.99448
# Valid data:  [148] epoch,  loss: 0.15577, accuracy: 0.93607 precision: 0.87539, auc: 0.97948
# Epoch number: 149
# [[4687   58]
#  [  85 2489]]
# [[495  40]
#  [ 12 282]]
# Training data:  [149] epoch,  loss: 0.06380, accuracy: 0.98046, precision: 0.97723, auc: 0.99122
# Valid data:  [149] epoch,  loss: 0.15465, accuracy: 0.93727 precision: 0.87578, auc: 0.97695
# Epoch number: 150
# [[4683   62]
#  [  72 2502]]
# [[503  32]
#  [ 13 281]]
# Training data:  [150] epoch,  loss: 0.05481, accuracy: 0.98169, precision: 0.97582, auc: 0.99583
# Valid data:  [150] epoch,  loss: 0.14675, accuracy: 0.94572 precision: 0.89776, auc: 0.97852
# Finished Training

# %% [markdown]
# ### **Evaluating our model**

# %%
model.load()

# %%
model.training_data()

# %% [markdown]
# ### Results on valid and test subsets

# %%
valid = DataLoader(dataset=valid_data, batch_size=inference_batch_size, shuffle=False, num_workers=16)
test = DataLoader(dataset=test_data, batch_size=inference_batch_size, shuffle=False, num_workers=16)

# %%
model.run_epoch(valid,(train_batch_size, inference_batch_size), data_type='valid')
# Out:
# [[503  32]
#  [ 13 281]]
# (0.1467475692558454, 0.94571775, 0.89776355, 0.9785237485230264)

# %%
model.run_epoch(test,(train_batch_size, inference_batch_size), data_type='valid')
# Out:
# [[720  85]
#  [ 83 247]]
# (0.7383397402751862, 0.85198236, 0.7439759, 0.8588292304677739)

# %%
idx = random.randrange(0, sample_dataset.__len__())
img, target, _, _ = test_data.__getitem__(idx)
model.class_activation_map(img, target)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Target is: 0
# Prediction is: 0

# %%
model.show_errors(dataset)
# Out:
# for species T. boeoticum we have accuracy: 0.7310344827586207
# for species T. vavilovii we have accuracy: 0.7818181818181819
# for species T. durum we have accuracy: 0.9926402943882244
# for species T. dicoccum we have accuracy: 0.9939975990396158
# for species T. monococcum we have accuracy: 0.9740458015267176
# for species T. carthlicum we have accuracy: 0.9865853658536585
# for species T. aethiopicum we have accuracy: 0.9953846153846154
# for species T. dicoccoides we have accuracy: 0.92573402417962
# for species T. petropavlovskyi we have accuracy: 0.9973262032085561
# for species T. timopheevii we have accuracy: 0.9988571428571429
# for species T. compactum we have accuracy: 0.9777777777777777
# for species T. macha we have accuracy: 0.992
# for species T. spelta we have accuracy: 1.0
# for species T. turgidum we have accuracy: 0.9949152542372881
# for species T. urartu we have accuracy: 0.984
# for species T. polonicum we have accuracy: 0.8872727272727273
# for species T. yunnanense we have accuracy: 0.9769230769230769
# for species T. aestivum we have accuracy: 1.0
